# %% [markdown]
# ## Networkx

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\ljeng\appdata\roaming\python\python38\site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
G=nx.Graph()
G.add_node("A")
G.add_node("B")
G.add_node("C")

G.add_edge("A","B")
G.add_edge("C","B")
G.add_edge("A","C")
G.add_edge("A","D")
G.add_edge("A","A")

nx.draw_networkx(G,node_size=850, node_color='red', width=5, edge_color='blue')
plt.show()

# %%
G=nx.Graph()
G.add_nodes_from([1,2,3,4,5,6])
G.add_edges_from([(1,2),(1,1),(2,3),(3,6),(4,6),(5,6)])
nx.draw_networkx(G,node_size=850, node_color='red', width=5, edge_color='blue')
plt.show()

# %%
G=nx.DiGraph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(1,3),(1,4),(3,4),(4,3)])
nx.draw_networkx(G)
plt.show()

# %%
# following dict shows u how 5 people follows each other on Insta
# create a directed nextworkx graph

instagram = {
    'person1': [0,1,1,0,1], 
    'person2': [0,0,1,0,1], 
    'person3': [1,1,0,1,1],
    'person4': [1,1,1,0,0], 
    'person5': [1,1,0,0,0]
}

G=nx.DiGraph()
G.add_nodes_from(instagram.keys())

for person in instagram.keys():
    for conn in range(len(instagram[person])):
        if instagram[person][conn] == 1:
            G.add_edge(person,f'person{(conn+1)}')

nx.draw_networkx(G)
plt.show()

# %%
G=nx.DiGraph(np.array(list(instagram.values())))
nx.draw_networkx(G,labels={0:'person1',1:'person2',2:'person3',3:'person4',4:'person5'})
plt.show()

# %% [markdown]
# ## Folium

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.19.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
map1 = folium.Map(location=[22.9912, 72.4884], zoom_start=12, tiles='OpenStreetMap') # max zoom = 20
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c3e10dd03a33e83aea372ec0922722a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c3e10dd03a33e83aea372ec0922722a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c3e10dd03a33e83aea372ec0922722a = L.map(
#                 &quot;map_3c3e10dd03a33e83aea372ec0922722a&quot;,
#                 {
#                     center: [22.9912, 72.4884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38dcb1063baa1d8f88b736ec6b1cb81e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c3e10dd03a33e83aea372ec0922722a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map1 = folium.Map(location=[22.9912, 72.4884], zoom_start=12, tiles='OpenStreetMap') # max zoom = 20


# marker
folium.Marker(
    location=[23.2152, 72.6682],
    tooltip='This is parking location', 
    popup=folium.Popup("""<h2>Station1</h2><br/>
    <a href='https://www.ljku.edu.in'>Click Here</a>""", max_width=500),
    icon=folium.Icon(color="red", icon="info")
).add_to(map1) # radius is in meters

# radius
folium.Circle(
    location=[23.2152, 72.6682], 
    radius=10000,
    fill_color="#f03", 
    fill=True, 
    fill_opacity=0.3,
    tooltip='This is geo-fenced area', 
    popup=folium.Popup("""<h2>Geo-Fence</h2><br/>
    <h5>This is a new line</h5><br/>
    <a href='https://www.ljku.edu.in'>Click Here</a>""", max_width=500)
).add_to(map1) # radius is in meters

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6317dc0d6a07eb85dd28201346efbc6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6317dc0d6a07eb85dd28201346efbc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6317dc0d6a07eb85dd28201346efbc6 = L.map(
#                 &quot;map_f6317dc0d6a07eb85dd28201346efbc6&quot;,
#                 {
#                     center: [22.9912, 72.4884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7e27d9d9ad07528b09f541919bc8605 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f6317dc0d6a07eb85dd28201346efbc6);
#
#
#             var marker_223a6d8a825f775c7961f786b354b022 = L.marker(
#                 [23.2152, 72.6682],
#                 {}
#             ).addTo(map_f6317dc0d6a07eb85dd28201346efbc6);
#
#
#             var icon_f355f45586c013b0ed1bb0fd40272151 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_223a6d8a825f775c7961f786b354b022.setIcon(icon_f355f45586c013b0ed1bb0fd40272151);
#
#
#         var popup_9be95cf1ea8cc423dc91dc4e5a2e2783 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_85fb54da44695d2f764ecf0b46ddd246 = $(`&lt;div id=&quot;html_85fb54da44695d2f764ecf0b46ddd246&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h2&gt;Station1&lt;/h2&gt;&lt;br/&gt;     &lt;a href=&#x27;https://www.ljku.edu.in&#x27;&gt;Click Here&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_9be95cf1ea8cc423dc91dc4e5a2e2783.setContent(html_85fb54da44695d2f764ecf0b46ddd246);
#
#
#
#         marker_223a6d8a825f775c7961f786b354b022.bindPopup(popup_9be95cf1ea8cc423dc91dc4e5a2e2783)
#         ;
#
#
#
#
#             marker_223a6d8a825f775c7961f786b354b022.bindTooltip(
#                 `&lt;div&gt;
#                      This is parking location
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_8de476d0b16241dac3f5a19e216776fa = L.circle(
#                 [23.2152, 72.6682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f03&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f6317dc0d6a07eb85dd28201346efbc6);
#
#
#         var popup_ba6e3d0d864632b9a581cf1d7c1f0b01 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_2cf5a78555ba8a5d9c136f83c27e6fc8 = $(`&lt;div id=&quot;html_2cf5a78555ba8a5d9c136f83c27e6fc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h2&gt;Geo-Fence&lt;/h2&gt;&lt;br/&gt;     &lt;h5&gt;This is a new line&lt;/h5&gt;&lt;br/&gt;     &lt;a href=&#x27;https://www.ljku.edu.in&#x27;&gt;Click Here&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_ba6e3d0d864632b9a581cf1d7c1f0b01.setContent(html_2cf5a78555ba8a5d9c136f83c27e6fc8);
#
#
#
#         circle_8de476d0b16241dac3f5a19e216776fa.bindPopup(popup_ba6e3d0d864632b9a581cf1d7c1f0b01)
#         ;
#
#
#
#
#             circle_8de476d0b16241dac3f5a19e216776fa.bindTooltip(
#                 `&lt;div&gt;
#                      This is geo-fenced area
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Police Department Problem

# %%
departs = pd.read_csv('PD.csv')
df = pd.DataFrame(departs)
x_coords = df['X']
y_coords = df['Y']
category = df['Category']
map1 = folium.Map(location=[37.7740,-122.4194],zoom_start=13)

# for x,y,cat in zip(x_coords, y_coords, category):
#     folium.Marker(
#         location=[y, x],
#         popup=cat
#     ).add_to(map1) # radius is in meters

for i in range(100):
    folium.Marker(
        location=[y_coords[i], x_coords[i]],
        popup=category[i]
    ).add_to(map1) # radius is in meters

map1.save('crime.html')
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6ea0733c21f5dce4bb4424b4ec3e5eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6ea0733c21f5dce4bb4424b4ec3e5eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6ea0733c21f5dce4bb4424b4ec3e5eb = L.map(
#                 &quot;map_c6ea0733c21f5dce4bb4424b4ec3e5eb&quot;,
#                 {
#                     center: [37.774, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11de556319e0ede8b9f58928557c4a4d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#             var marker_c8d229ccbd3ecb62b837b9f5969fb990 = L.marker(
#                 [37.77542071, -122.40340479999999],
#                 {}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#         var popup_1e229710ad5a66444d559c582d74257c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_293a2eb0444ec5229707974ab203db35 = $(`&lt;div id=&quot;html_293a2eb0444ec5229707974ab203db35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_1e229710ad5a66444d559c582d74257c.setContent(html_293a2eb0444ec5229707974ab203db35);
#
#
#
#         marker_c8d229ccbd3ecb62b837b9f5969fb990.bindPopup(popup_1e229710ad5a66444d559c582d74257c)
#         ;
#
#
#
#
#             var marker_0b30dce834e6bf14ab14ba3af12ab50a = L.marker(
#                 [37.77542071, -122.40340479999999],
#                 {}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#         var popup_395a5a216abe378d3b4c13125c80b242 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_511edecd5344e2964c82e3104f776fec = $(`&lt;div id=&quot;html_511edecd5344e2964c82e3104f776fec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_395a5a216abe378d3b4c13125c80b242.setContent(html_511edecd5344e2964c82e3104f776fec);
#
#
#
#         marker_0b30dce834e6bf14ab14ba3af12ab50a.bindPopup(popup_395a5a216abe378d3b4c13125c80b242)
#         ;
#
#
#
#
#             var marker_550c89049ad612f6ffbc477e245d1d63 = L.marker(
#                 [37.72998097, -122.38885619999999],
#                 {}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#         var popup_78544ddf326057305b9c07a894f4597c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8402ad4f5ae77b0a0c145625ca88ed3 = $(`&lt;div id=&quot;html_e8402ad4f5ae77b0a0c145625ca88ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_78544ddf326057305b9c07a894f4597c.setContent(html_e8402ad4f5ae77b0a0c145625ca88ed3);
#
#
#
#         marker_550c89049ad612f6ffbc477e245d1d63.bindPopup(popup_78544ddf326057305b9c07a894f4597c)
#         ;
#
#
#
#
#             var marker_87f6b27123c6c0a41b31cd28aa56204e = L.marker(
#                 [37.78578838, -122.41297050000001],
#                 {}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#         var popup_799aeaf7cd9f3416afcaa045226ad751 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bb321d704d30b299da3d8aa10fa932b = $(`&lt;div id=&quot;html_6bb321d704d30b299da3d8aa10fa932b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_799aeaf7cd9f3416afcaa045226ad751.setContent(html_6bb321d704d30b299da3d8aa10fa932b);
#
#
#
#         marker_87f6b27123c6c0a41b31cd28aa56204e.bindPopup(popup_799aeaf7cd9f3416afcaa045226ad751)
#         ;
#
#
#
#
#             var marker_51838e7dafebf8fcffe4209cd36b1824 = L.marker(
#                 [37.76505012, -122.41967179999999],
#                 {}
#             ).addTo(map_c6ea0733c21f5dce4bb4424b4ec3e5eb);
#
#
#         var popup_5c0890efdef4439a995882d02d128858 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8d24d2e384740e82875665ab4a29249 = $(`&lt;div id=&quot;html_e8d24d2e384740e82875665ab4a29249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_5c0890efdef4439a995882d02d128858.setContent(html_e8d24d2e384740e82875665ab4a29249);
#
#
#
#         marker_51838e7dafebf8fcffe4209cd36b1824.bindPopup(popup_5c0890efdef4439a995882d02d128858)
#         ;
#
#
#
#
#             var marker_14acd0543f574c7a4a378a4c8a12f78a = L.marker(
