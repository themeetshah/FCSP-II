# %%
# Entropy = -Sum(probability*log(base 2)Probability)
# entropy: measure of noise or irregularity in a column
# information_gain = target_col_entropy - pred_col_entropy

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kavit88/Linear-Regression/main/decision.csv')
x=df.drop('Job Offered',axis=1)
y=df['Job Offered']

dt = DecisionTreeClassifier(criterion='entropy', max_depth=2)
dt.fit(x,y)
y_pred=dt.predict(x)

print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.88      0.93         8
#
#     accuracy                           0.94        18
#    macro avg       0.95      0.94      0.94        18
# weighted avg       0.95      0.94      0.94        18

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plot_tree(dt, filled=True, feature_names=x.columns)
plt.show()
