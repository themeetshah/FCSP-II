# %% [markdown]
# ## Write a python program to scrape the following file. Extract the data regarding the given mobiles and create dataframe accordingly:-
#
# - Link to the file :-
# [Indeed Jobs]('https://github.com/patelmanishv/Sem4Data/blob/master/Data/indeed%20jobs.html')
# - Required Output
#
# ![image.png](attachment:image.png)

# %%
###---Write code here
