# %% [markdown]
# ## Write a python program to scrape the following file. Extract the data regarding the given mobiles and create dataframe accordingly:-
#
# #### Link to the file :-
# [Flipkart Mobiles](https://github.com/patelmanishv/Sem4Data/blob/master/Data/flipkart.html)
#
# ## Required Output
# ![image.png](attachment:cd3fcaf6-ede8-413d-9aa2-7ccf158ce31a.png))

# %%
## Write your code here--------------
